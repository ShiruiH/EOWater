# %%
import ee

# %%
# Authenticate and Initialize ee
ee.Authenticate()
ee.Initialize(project='nsw-dpe-gee-tst')

# %%
# Define the ImageCollection wish to delete
collection = ee.ImageCollection('projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles')

# %%
# Function to delete an image.
def delete_image(image):
    image_id = image.get('system:id').getInfo()
    ee.data.deleteAsset(image_id)
    print(f'Deleted {image_id}')

# %%
# Get the list of images to delete.
image_list = collection.toList(collection.size())

# Loop through the list and delete each image.
for i in range(image_list.size().getInfo()):
    image = ee.Image(image_list.get(0))
    delete_image(image)

print('Images deleted successfully. Now you can re-upload tiles using 03_Ingest_tiles_to_EEAssets.ipynb')
# Out:
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55HEE
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55HFE
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JDG
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JEF
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JEG
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JFF
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JFG
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JFH
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JGF
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JGG
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JGH
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T55JGJ
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T56JKL
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T56JKM
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T56JKN
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231213T001111_20231213T001105_T56JKP
# Deleted projects/nsw-dpe-gee-tst/assets/OFS/exp_baseOFS_Sentinel2_tiles/20231214T002709_20231214T003459_T55JCG
# Images deleted successfully. Now you can reupload tiles using 03_Ingest_tiles_to_EEAssets.ipynb
